# %% [markdown]
# <a href="https://colab.research.google.com/github/241b211-eng/Aps_lab_2026/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):
    distances = {}
    visited = []
    parent = {}

    for node in graph:
        distances[node] = float('inf')

        parent[node] = None

    distances[start] = 0

    while len(visited) < len(graph):
        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor in graph[min_node]:
            weight = graph[min_node][neighbor]
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                parent[neighbor] = min_node

    return distances, parent

graph = {}

n = int(input("Enter number of nodes: "))

for i in range(n):
    node = input("Enter node name: ")
    graph[node] = {}

    m = int(input(f"Enter number of neighbors of {node}: "))
    for j in range(m):
        neighbor = input("Enter neighbor: ")
        weight = int(input("Enter weight: "))
        graph[node][neighbor] = weight

start = input("Enter source node: ")

distances, parent = dijkstra(graph, start)

def print_path(parent, node):
    if parent[node] is None:
        print(node, end="")
        return
    print_path(parent, parent[node])
    print(" ->", node, end="")

print("\nShortest Paths:")
for node in graph:
    print(f"\nPath to {node}:", end=" ")
    print_path(parent, node)
    print(f" | Distance = {distances[node]}")
# Out:
# Enter number of nodes: 6
# Enter node name: a
# Enter number of neighbors of a: 2
# Enter neighbor: b
# Enter weight: 4
# Enter neighbor: c
# Enter weight: 2
# Enter node name: b
# Enter number of neighbors of b: 3
# Enter neighbor: a
# Enter weight: 4
# Enter neighbor: c
# Enter weight: 5
# Enter neighbor: d
# Enter weight: 16
# Enter node name: c
# Enter number of neighbors of c: 3
# Enter neighbor: a
# Enter weight: 2
# Enter neighbor: b
# Enter weight: 5
# Enter neighbor: d
# Enter weight: 3
# Enter node name: d
# Enter number of neighbors of d: 3
# Enter neighbor: b
# Enter weight: 10
# Enter neighbor: c
# Enter weight: 3
# Enter neighbor: e
# Enter weight: 2
# Enter node name: e
# Enter number of neighbors of e: 2
# Enter neighbor: d
# Enter weight: 2
# Enter neighbor: f
# Enter weight: 3
# Enter node name: f
# Enter number of neighbors of f: 1
# Enter neighbor: e
# Enter weight: 3
# Enter source node: a
#
# Shortest Paths:
#
# Path to a: a | Distance = 0
#
# Path to b: a -> b | Distance = 4
#
# Path to c: a -> c | Distance = 2
#
# Path to d: a -> c -> d | Distance = 5
#
# Path to e: a -> c -> d -> e | Distance = 7
#
# Path to f: a -> c -> d -> e -> f | Distance = 10

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

distances, parent = dijkstra(graph, 'A')

for node in distances:
    print("Distance from A to", node, "=", distances[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
